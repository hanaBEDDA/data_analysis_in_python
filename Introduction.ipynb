# %%
import pandas as pd
df=pd.read_csv('worldometer.csv')
df
# Out:
#             Country/Region      Continent    Population  TotalCases  NewCases  \
# 0                      USA  North America  3.311981e+08     5032179       NaN
# 1                   Brazil  South America  2.127107e+08     2917562       NaN
# 2                    India           Asia  1.381345e+09     2025409       NaN
# 3                   Russia         Europe  1.459409e+08      871894       NaN
# 4             South Africa         Africa  5.938157e+07      538184       NaN
# ..                     ...            ...           ...         ...       ...
# 204             Montserrat  North America  4.992000e+03          13       NaN
# 205  Caribbean Netherlands  North America  2.624700e+04          13       NaN
# 206       Falkland Islands  South America  3.489000e+03          13       NaN
# 207           Vatican City         Europe  8.010000e+02          12       NaN
# 208         Western Sahara         Africa  5.986820e+05          10       NaN
#
# ...

# %%
df.head(3)
# Out:
#   Country/Region      Continent    Population  TotalCases  NewCases  \
# 0            USA  North America  3.311981e+08     5032179       NaN
# 1         Brazil  South America  2.127107e+08     2917562       NaN
# 2          India           Asia  1.381345e+09     2025409       NaN
#
#    TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 0     162804.0        NaN       2576668.0           NaN    2292707.0
# 1      98644.0        NaN       2047660.0           NaN     771258.0
# 2      41638.0        NaN       1377384.0           NaN     606387.0
#
#    Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 0           18296.0           15194.0          492.0  63139605.0
# 1            8318.0           13716.0          464.0  13206188.0
# 2            8944.0            1466.0           30.0  22149351.0
#
#    Tests/1M pop      WHO Region
# 0      190640.0        Americas
# 1       62085.0        Americas
# 2       16035.0  South-EastAsia

# %%
df.tail(4)
# Out:
#             Country/Region      Continent  Population  TotalCases  NewCases  \
# 205  Caribbean Netherlands  North America     26247.0          13       NaN
# 206       Falkland Islands  South America      3489.0          13       NaN
# 207           Vatican City         Europe       801.0          12       NaN
# 208         Western Sahara         Africa    598682.0          10       NaN
#
#      TotalDeaths  NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# 205          NaN        NaN             7.0           NaN          6.0
# 206          NaN        NaN            13.0           NaN          0.0
# 207          NaN        NaN            12.0           NaN          0.0
# 208          1.0        NaN             8.0           NaN          1.0
#
#      Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# 205               NaN             495.0            NaN       424.0
# 206               NaN            3726.0            NaN      1816.0
# ...

# %%
df["TotalCases"]
# Out:
# 0      5032179
# 1      2917562
# 2      2025409
# 3       871894
# 4       538184
#         ...
# 204         13
# 205         13
# 206         13
# 207         12
# 208         10
# Name: TotalCases, Length: 209, dtype: int64

# %%
df["TotalCases"].head()
# Out:
# 0    5032179
# 1    2917562
# 2    2025409
# 3     871894
# 4     538184
# Name: TotalCases, dtype: int64

# %%
df.TotalCases.head()
# Out:
# 0    5032179
# 1    2917562
# 2    2025409
# 3     871894
# 4     538184
# Name: TotalCases, dtype: int64

# %%
Africa_df=df[df['Continent']== "Africa"]
Africa_df
# Out:
#             Country/Region Continent   Population  TotalCases  NewCases  \
# 4             South Africa    Africa   59381566.0      538184       NaN
# 26                   Egypt    Africa  102516525.0       95006       NaN
# 45                 Nigeria    Africa  206606300.0       45244       NaN
# 50                   Ghana    Africa   31133483.0       39642       NaN
# 54                 Algeria    Africa   43926079.0       33626       NaN
# 56                 Morocco    Africa   36953359.0       29644       NaN
# 61                   Kenya    Africa   53881160.0       24411       NaN
# 66                Ethiopia    Africa  115223736.0       20900       NaN
# 70                Cameroon    Africa   26606188.0       17718       NaN
# 71             Ivory Coast    Africa   26437950.0       16447       NaN
# 77              Madagascar    Africa   27755708.0       12526       NaN
# 78                   Sudan    Africa   43943536.0       11780       NaN
# ...

# %%
Africa_df.index
# Out:
# Int64Index([  4,  26,  45,  50,  54,  56,  61,  66,  70,  71,  77,  78,  80,
#              82,  85,  87,  90,  92,  97,  99, 100, 102, 104, 105, 108, 111,
#             112, 113, 116, 117, 118, 120, 124, 125, 127, 128, 130, 132, 134,
#             138, 139, 142, 143, 144, 149, 150, 151, 152, 155, 158, 161, 163,
#             164, 166, 169, 184, 208],
#            dtype='int64')

# %%
Africa_df.set_index("Population")
# Out:
#                     Country/Region Continent  TotalCases  NewCases  \
# Population
# 59381566.0            South Africa    Africa      538184       NaN
# 102516525.0                  Egypt    Africa       95006       NaN
# 206606300.0                Nigeria    Africa       45244       NaN
# 31133483.0                   Ghana    Africa       39642       NaN
# 43926079.0                 Algeria    Africa       33626       NaN
# 36953359.0                 Morocco    Africa       29644       NaN
# 53881160.0                   Kenya    Africa       24411       NaN
# 115223736.0               Ethiopia    Africa       20900       NaN
# 26606188.0                Cameroon    Africa       17718       NaN
# 26437950.0             Ivory Coast    Africa       16447       NaN
# 27755708.0              Madagascar    Africa       12526       NaN
# 43943536.0                   Sudan    Africa       11780       NaN
# 16783877.0                 Senegal    Africa       10715       NaN
# ...

# %%
Africa_df=Africa_df.set_index("Population")

# %%
Africa_df.head()
# Out:
#             Country/Region Continent  TotalCases  NewCases  TotalDeaths  \
# Population
# 59381566.0    South Africa    Africa      538184       NaN       9604.0
# 102516525.0          Egypt    Africa       95006       NaN       4951.0
# 206606300.0        Nigeria    Africa       45244       NaN        930.0
# 31133483.0           Ghana    Africa       39642       NaN        199.0
# 43926079.0         Algeria    Africa       33626       NaN       1273.0
#
#              NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Population
# 59381566.0         NaN        387316.0           NaN     141264.0
# 102516525.0        NaN         48898.0           NaN      41157.0
# 206606300.0        NaN         32430.0           NaN      11884.0
# 31133483.0         NaN         36384.0           NaN       3059.0
# 43926079.0         NaN         23238.0           NaN       9115.0
#
#              Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# Population
# ...

# %%
df["TotalTests"].plot()
# Out:
# <AxesSubplot:>

# %%
df["TotalDeaths"].plot()
# Out:
# <AxesSubplot:>
