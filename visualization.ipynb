# %%
import pandas as pd

# %%
df=pd.read_csv('worldometer.csv')
Africa_df=df[df["Continent"]=='Africa']
Afset=Africa_df.set_index("Country/Region")
Afset
# Out:
#                       Continent   Population  TotalCases  NewCases  \
# Country/Region
# South Africa             Africa   59381566.0      538184       NaN
# Egypt                    Africa  102516525.0       95006       NaN
# Nigeria                  Africa  206606300.0       45244       NaN
# Ghana                    Africa   31133483.0       39642       NaN
# Algeria                  Africa   43926079.0       33626       NaN
# Morocco                  Africa   36953359.0       29644       NaN
# Kenya                    Africa   53881160.0       24411       NaN
# Ethiopia                 Africa  115223736.0       20900       NaN
# Cameroon                 Africa   26606188.0       17718       NaN
# Ivory Coast              Africa   26437950.0       16447       NaN
# Madagascar               Africa   27755708.0       12526       NaN
# Sudan                    Africa   43943536.0       11780       NaN
# Senegal                  Africa   16783877.0       10715       NaN
# ...

# %%
df.values
# Out:
# array([['USA', 'North America', 331198130.0, ..., 63139605.0, 190640.0,
#         'Americas'],
#        ['Brazil', 'South America', 212710692.0, ..., 13206188.0, 62085.0,
#         'Americas'],
#        ['India', 'Asia', 1381344997.0, ..., 22149351.0, 16035.0,
#         'South-EastAsia'],
#        ...,
#        ['Falkland Islands', 'South America', 3489.0, ..., 1816.0,
#         520493.0, nan],
#        ['Vatican City', 'Europe', 801.0, ..., nan, nan, 'Europe'],
#        ['Western Sahara', 'Africa', 598682.0, ..., nan, nan, 'Africa']],
#       dtype=object)

# %%
set(df['Country/Region'].values.tolist())
# Out:
# {'Afghanistan',
#  'Albania',
#  'Algeria',
#  'Andorra',
#  'Angola',
#  'Antigua and Barbuda',
#  'Argentina',
#  'Armenia',
#  'Aruba',
#  'Australia',
#  'Austria',
#  'Azerbaijan',
#  'Bahamas',
#  'Bahrain',
#  'Bangladesh',
#  'Barbados',
#  'Belarus',
#  'Belgium',
#  'Belize',
#  'Benin',
#  'Bermuda',
#  'Bhutan',
#  'Bolivia',
#  'Bosnia and Herzegovina',
#  'Botswana',
#  'Brazil',
#  'Brunei ',
#  'Bulgaria',
#  'Burkina Faso',
#  'Burundi',
#  'CAR',
#  'Cabo Verde',
#  'Cambodia',
#  'Cameroon',
#  'Canada',
#  'Caribbean Netherlands',
#  'Cayman Islands',
#  'Chad',
#  'Channel Islands',
#  'Chile',
#  'Colombia',
#  'Comoros',
#  'Congo',
#  'Costa Rica',
#  'Croatia',
#  'Cuba',
#  'Curaçao',
#  'Cyprus',
#  'Czechia',
#  'DRC',
#  'Denmark',
#  'Diamond Princess',
#  'Djibouti',
#  'Dominica',
#  'Dominican Republic',
#  'Ecuador',
#  'Egypt',
#  'El Salvador',
#  'Equatorial Guinea',
#  'Eritrea',
#  'Estonia',
#  'Eswatini',
#  'Ethiopia',
#  'Faeroe Islands',
# ...

# %%
df['Continent'].unique()
# Out:
# array(['North America', 'South America', 'Asia', 'Europe', 'Africa',
#        'Australia/Oceania', nan], dtype=object)

# %%
Afset["Population"].plot()
# Out:
# <AxesSubplot:xlabel='Country/Region'>

# %%
Afset["TotalCases"].plot()
# Out:
# <AxesSubplot:xlabel='Country/Region'>

# %%
Afset['TotalCases'].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Country/Region'>

# %%
Afset.index
# Out:
# Index(['South Africa', 'Egypt', 'Nigeria', 'Ghana', 'Algeria', 'Morocco',
#        'Kenya', 'Ethiopia', 'Cameroon', 'Ivory Coast', 'Madagascar', 'Sudan',
#        'Senegal', 'DRC', 'Gabon', 'Guinea', 'Zambia', 'Mauritania', 'Djibouti',
#        'Libya', 'Equatorial Guinea', 'CAR', 'Malawi', 'Zimbabwe', 'Congo',
#        'Somalia', 'Mayotte', 'Eswatini', 'Cabo Verde', 'Namibia', 'Mali',
#        'South Sudan', 'Mozambique', 'Rwanda', 'Guinea-Bissau', 'Benin',
#        'Sierra Leone', 'Tunisia', 'Angola', 'Liberia', 'Uganda',
#        'Burkina Faso', 'Niger', 'Togo', 'Chad', 'Gambia',
#        'Sao Tome and Principe', 'Botswana', 'Lesotho', 'Réunion', 'Tanzania',
#        'Comoros', 'Burundi', 'Mauritius', 'Eritrea', 'Seychelles',
#        'Western Sahara'],
#       dtype='object', name='Country/Region')

# %%
Afset.sort_index(inplace=True)
df['TotalCases'].rolling(25).mean().plot()
# Out:
# <AxesSubplot:>

# %%
Afset['Activecases']=df['TotalCases'].rolling(25).mean()

# %% [raw]
# Afset.tail(4)

# %%
Afset.head()
# Out:
#                Continent  Population  TotalCases  NewCases  TotalDeaths  \
# Country/Region
# Algeria           Africa  43926079.0       33626       NaN       1273.0
# Angola            Africa  32956300.0        1483       NaN         64.0
# Benin             Africa  12151976.0        1936       NaN         38.0
# Botswana          Africa   2356075.0         804       NaN          2.0
# Burkina Faso      Africa  20954852.0        1158       NaN         54.0
#
#                 NewDeaths  TotalRecovered  NewRecovered  ActiveCases  \
# Country/Region
# Algeria               NaN         23238.0           NaN       9115.0
# Angola                NaN           520.0           NaN        899.0
# Benin                 NaN          1600.0           NaN        298.0
# Botswana              NaN            63.0           NaN        739.0
# Burkina Faso          NaN           961.0           NaN        143.0
#
#                 Serious,Critical  Tot Cases/1M pop  Deaths/1M pop  TotalTests  \
# ...

# %%
Afset=df.copy()[df['Continent']=='Africa']
Afset.set_index("Country/Region",inplace=True)
Afset.sort_index(inplace=True)
Afset['Activecases']=df['TotalCases'].rolling(25).mean()

# %%
graph_df=pd.DataFrame()

for Continent in df['Continent'].unique()[:16]:
    print(Continent)
    Continent_df=df.copy()[df['Continent']==Continent]
    Continent_df.set_index('Country/Region',inplace=True)
    Continent_df.sort_index(inplace=True)
   
    Continent_df[f'{Continent}_TotalCases']=Continent_df['TotalDeaths'].rolling(2).mean()
    if graph_df.empty:
        graph_df=Continent_df[f'{Continent}_TotalCases']
        
    else:
         graph_df=graph_df.join(Continent_df[f'{Continent}_TotalCases'])
print(graph_df)
# Out:
# North America
# South America
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\QUICKT~1\AppData\Local\Temp/ipykernel_3080/564140834.py in <module>
#      12
#      13     else:
# ---> 14          graph_df=graph_df.join(Continent_df[f'{Continent}_TotalCases'])
#      15 print(graph_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'join'
