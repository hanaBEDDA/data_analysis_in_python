# %%
import pandas as pd
import os
os.getcwd()
os.chdir('Desktop')

# %%
df=pd.read_csv('covid.csv',encoding='latin')

# %%
df=pd.read_csv('covid.csv')
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
df.describe()
# Out:
#                 Lat          Long     Confirmed         Deaths     Recovered  \
# count  49068.000000  49068.000000  4.906800e+04   49068.000000  4.906800e+04
# mean      21.433730     23.528236  1.688490e+04     884.179160  7.915713e+03
# std       24.950320     70.442740  1.273002e+05    6313.584411  5.480092e+04
# min      -51.796300   -135.000000  0.000000e+00       0.000000  0.000000e+00
# 25%        7.873054    -15.310100  4.000000e+00       0.000000  0.000000e+00
# 50%       23.634500     21.745300  1.680000e+02       2.000000  2.900000e+01
# 75%       41.204380     80.771797  1.518250e+03      30.000000  6.660000e+02
# max       71.706900    178.065000  4.290259e+06  148011.000000  1.846641e+06
#
#              Active
# count  4.906800e+04
# mean   8.085012e+03
# std    7.625890e+04
# min   -1.400000e+01
# 25%    0.000000e+00
# 50%    2.600000e+01
# 75%    6.060000e+02
# max    2.816444e+06

# %%
gb=df.groupby('WHO Region')
gb.get_group('Africa').set_index('Date').head()
# Out:
#            Province/State Country/Region      Lat     Long  Confirmed  Deaths  \
# Date
# 2020-01-22            NaN        Algeria  28.0339   1.6596          0       0
# 2020-01-22            NaN         Angola -11.2027  17.8739          0       0
# 2020-01-22            NaN          Benin   9.3077   2.3158          0       0
# 2020-01-22            NaN   Burkina Faso  12.2383  -1.5616          0       0
# 2020-01-22            NaN     Cabo Verde  16.5388 -23.0418          0       0
#
#             Recovered  Active WHO Region
# Date
# 2020-01-22          0       0     Africa
# 2020-01-22          0       0     Africa
# 2020-01-22          0       0     Africa
# 2020-01-22          0       0     Africa
# 2020-01-22          0       0     Africa

# %%
group=df['Confirmed'].groupby(df['Country/Region'])
group

# %%
len(list(df['Confirmed'].groupby(df['Country/Region'])))
# Out:
# 187

# %%
list(df['Confirmed'].groupby(df['Country/Region']))
# Out:
# [('Afghanistan',
#   0            0
#   261          0
#   522          0
#   783          0
#   1044         0
#            ...
#   47763    35928
#   48024    35981
#   48285    36036
#   48546    36157
#   48807    36263
#   Name: Confirmed, Length: 188, dtype: int64),
#  ('Albania',
#   1           0
#   262         0
#   523         0
#   784         0
#   1045        0
#            ...
#   47764    4466
#   48025    4570
#   48286    4637
#   48547    4763
#   48808    4880
#   Name: Confirmed, Length: 188, dtype: int64),
#  ('Algeria',
#   2            0
#   263          0
#   524          0
#   785          0
#   1046         0
#            ...
#   47765    25484
#   48026    26159
#   48287    26764
#   48548    27357
#   48809    27973
#   Name: Confirmed, Length: 188, dtype: int64),
#  ('Andorra',
#   3          0
#   264        0
#   525        0
#   786        0
#   1047       0
#           ...
#   47766    889
#   48027    897
#   48288    897
#   48549    897
# ...

# %%
series=pd.Series(df['Confirmed'])
func_list=[min, sum, max, 'mean']
series.agg(func_list)
# Out:
# min     0.000000e+00
# sum     8.285085e+08
# max     4.290259e+06
# mean    1.688490e+04
# Name: Confirmed, dtype: float64

# %%
series=pd.Series(df['Deaths'])
func_list=[min, sum, max, 'mean']
series.agg(func_list)
# Out:
# min     0.000000e+00
# sum     4.338490e+07
# max     1.480110e+05
# mean    8.841792e+02
# Name: Deaths, dtype: float64

# %%
df.groupby(['WHO Region']).agg(
     {'Confirmed':['sum','min','max','mean']})
# Out:
#                        Confirmed
#                              sum min      max          mean
# WHO Region
# Africa                  21791827   0   452529   2414.874446
# Americas               402261194   0  4290259  46514.939177
# Eastern Mediterranean   74082892   0   293606  17911.724371
# Europe                 248879793   0   816680  16547.858577
# South-East Asia         55118365   0  1480073  29318.279255
# Western Pacific         26374411   0    82040   2550.716731

# %%
df.groupby(['WHO Region']).agg(
     {'Deaths':['sum','min','max','mean']})
# Out:
#                          Deaths
#                             sum min     max         mean
# WHO Region
# Africa                   439978   0    7067    48.756427
# Americas               19359292   0  148011  2238.586031
# Eastern Mediterranean   1924029   0   15912   465.190764
# Europe                 19271040   0   45759  1281.319149
# South-East Asia         1458134   0   33408   775.603191
# Western Pacific          932430   0    4512    90.176983

# %%
import numpy as np
df.replace(0,np.NaN).dropna(axis=1).head()
# Out:
#   Country/Region       Lat       Long        Date             WHO Region
# 0    Afghanistan  33.93911  67.709953  2020-01-22  Eastern Mediterranean
# 1        Albania  41.15330  20.168300  2020-01-22                 Europe
# 2        Algeria  28.03390   1.659600  2020-01-22                 Africa
# 3        Andorra  42.50630   1.521800  2020-01-22                 Europe
# 4         Angola -11.20270  17.873900  2020-01-22                 Africa
